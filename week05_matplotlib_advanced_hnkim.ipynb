# %% [markdown]
# ### matplotlib 중급

# %%
import sys
sys.version
# Out:
# '3.11.4 | packaged by Anaconda, Inc. | (main, Jul  5 2023, 13:38:37) [MSC v.1916 64 bit (AMD64)]'

# %%
import matplotlib.pyplot as plt

plt. plot([1,2,3,4], [10,20,30,40])
plt.title('plotting')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.show()

# %%
import matplotlib.pyplot as plt

plt. plot([1,2,3,4], [10,20,30,40], label='ascending')
plt. plot([1,2,3,4], [40,30,20,10], label='descending')

plt.title('legend')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt. plot([1,2,3,4], [10,20,30,40], color='skyblue', label ='skyblue')
plt. plot([1,2,3,4], [40,30,20,10], 'pink', label='pink')

plt.title('color')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt. plot([1,2,3,4], [10,20,30,40], color='skyblue', linestyle='--', label ='skyblue')
plt. plot([1,2,3,4], [40,30,20,10], 'pink', linestyle = ':',label='pink')

plt.title('linestyle')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt. plot([1,2,3,4], [10,20,30,40], color='skyblue', linestyle='--', marker='d',label ='skyblue')
plt. plot([1,2,3,4], [40,30,20,10], 'pink', linestyle = ':', marker= '^',label='pink')

plt.title('linestyle')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt. plot([1,2,3,4], [10,20,30,40], color='skyblue', linestyle='--', marker='d', linewidth=3, label ='skyblue')
plt. plot([1,2,3,4], [40,30,20,10], 'pink', linestyle = ':', marker= '^', linewidth=0.5,label='pink')

plt.title('linestyle')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([10,20,30,40], 'r', label='circle')
plt.plot([40,30,20,10], 'g', label="triangle up")

plt.title('marker')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.hist([1,1,2,3,4,5,6,7,8,10])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.hist([1,1,2,3,4,5,6,7,8,10], rwidth=0.9)
plt.show()

# %%
dice = [random.randint(1,6) for i in range(5)]
dice
# Out:
# [2, 2, 2, 3, 2]

# %%
random.choices(range(1,7), k = 10)
# Out:
# [3, 5, 4, 4, 4, 2, 2, 2, 6, 2]

# %%
import random
import matplotlib.pyplot as plt

dice =[]
for i in range(100000):
    dice.append(random.randint(1,6))
    
plt.hist(dice, bins =6)
plt.show()

# %%
import matplotlib.pyplot as plt
import random

result = []
for i in range(13):
    result.append(random.randint(1,1000))
    
print(sorted(result))
plt.boxplot(result)
plt.show()
# Out:
# [11, 27, 74, 177, 185, 214, 326, 411, 433, 495, 606, 705, 922]

# %%
import matplotlib.pyplot as plt
import random

result1 = []
result2 = []

for i in range(13):
    result1.append(random.randint(1, 500))
    result2.append(random.randint(501, 1000))
    
plt.boxplot(result1)
plt.boxplot(result2)
plt.show()

# %%
import matplotlib.pyplot as plt
import random

result1 = []
result2 = []

for i in range(13):
    result1.append(random.randint(1, 500))
    result2.append(random.randint(501, 1000))
    
plt.boxplot([result1,result2])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(10)

f1 = plt.figure(figsize =(10,2))
plt.plot(np,random.randint)

plt.title('d')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 7
#       4 np.random.seed(10)
#       6 f1 = plt.figure(figsize =(10,2))
# ----> 7 plt.plot(np,random.randint)
#       9 plt.title('d')
#      10 plt.show()
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:2812, in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:1688, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1445 """
#    1446 Plot y versus x as lines and/or markers.
#    1447
#    (...)
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(5,3))
plt.subplot(2,3,1)
plt.subplot(2,3,5)
plt.subplot(2,3,6)
# Out:
# <Axes: >

# %%
ax1 = plt.subplot(2,1,1)
plt.plot(np.random.randint(1,10,10), 'yo-')
plt.title('A tale of 2 subplots')
plt.ylabel('damped oscillation')
print(ax1)

ax2 = plt.subplot(2,1,2)
plt.plot(np.arange(10), np.arange(10)*2, 'r.-')
plt.xlabel('time(s)')
plt.ylabel('undamped')
print(ax2)
plt.tight_layout()
plt.show()
# Out:
# Axes(0.125,0.53;0.775x0.35)
# Axes(0.125,0.11;0.775x0.35)

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(2,2)

axes[0,0].plot([1,2,3,4])
axes[0,0].set_title("Subplot 1")

axes[0,1].plot([4,3,2,1])
axes[0,1].set_title("Subplot 2")

axes[1,0].hist([1,2,2,3,3,3,4,4,4,4], bins=5)
axes[1,0].set_title("Subplot 3")

axes[1,1].scatter([1,2,3,4], [4,3,2,1])
axes[1,1].set_title("Subplot 4")

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(7,5))

ax2=fig.add_subplot(2,2,2)
plt.plot(np.random.randn(50).cumsum(),'k--')

ax3= fig.add_subplot(2,2,3)
plt.plot(np.random.randn(50), 'p--')
